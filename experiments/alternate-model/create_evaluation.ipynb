# %%
import pandas as pd
import json

json_doc = {}

with open("agent-responses.json",'r',encoding='utf-8') as file:
    json_doc = json.load(file)

# %%
get_test_results = json_doc['test_results']
df = pd.DataFrame(get_test_results)
df = pd.DataFrame(get_test_results)
df.to_csv("evaluation.csv")
df.head()
# Out:
#                test_name                                             prompt  \
# 0          day-hike-gear  What essential gear do I need for a summer day...
# 1      overnight-camping  How should I prepare for my first overnight ca...
# 2  three-day-backpacking  I'm planning a 3-day backpacking trip in the m...
# 3       trail-difficulty  How do I know if a trail is appropriate for my...
# 4          winter-hiking  What additional gear and precautions do I need...
#
#                                             response  \
# 0  Absolutely! For a summer day hike on moderate ...
# 1  That’s an exciting step! Here’s a practical gu...
# 2  Great initiative! October mountain trips can b...
# 3  Great question! Choosing the right trail for y...
# 4  Winter hiking requires significantly more prep...
#
#                                          token_usage  \
# 0  {'prompt_tokens': 87, 'completion_tokens': 483...
# 1  {'prompt_tokens': 83, 'completion_tokens': 694...
# 2  {'prompt_tokens': 95, 'completion_tokens': 629...
# 3  {'prompt_tokens': 92, 'completion_tokens': 586...
# 4  {'prompt_tokens': 87, 'completion_tokens': 784...
#
#                                               run_id
# 0  resp_0bb275fa19763a79006ab14552bb6881909744909...
# 1  resp_02756e91cefaab35006ab14559d53c8190bbf9bad...
# 2  resp_0f1d90fa6d664a84006ab14561f0f08190a43dd42...
# 3  resp_0c143d8d7cd1b267006ab1456a9afc8190ba71994...
# 4  resp_0975c2b7ff375700006ab1457180ac8190b822ea7...
